# %%
import random
print("Welcome User\nWhat is your name? ")
name=input()
co=[]
so=[]
print("Select a choice for selection of songs:" )
print("1.Manually ")
print("2.Randomly Generated ")
opt=input()
if(opt=='1'):
    print("Instructions: ")
    print("1.Please select any number between 1 and 163206")
    print ("2.Songs are sorted according to popularity, number 1 being the most popular song")
    print("3.Type \"done\" when finished")
    while(1):
        t=input()
        if(t=="done"):
            break
        co.append(t)
if(opt=='2'):
    print("Number of songs to be generated: ")
    ns=input()
    for i in range(int(ns)):
        sn=random.randint(1,163206)
        co.append(str(sn))
file1=open("dataset\song_count_taste.txt","r")
file2=open('dataset/'+name+'songs.txt','w+')
j=1

c=sorted(set(co))
for line in file1:
    t=j
    fild=line.split(",")
    if str(t) in co:
        file2.write(fild[0]+","+str(random.randint(1,15))+","+fild[2])
    j=j+1

    
file2.close()
# Out:
# Welcome User
# What is your name?
# salil
# Select a choice for selection of songs:
# 1.Manually
# 2.Randomly Generated
# 2
# Number of songs to be generated:
# 6

# %%
import numpy as np
import matplotlib.pyplot as plt
ct={}
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.BOLD +color.CYAN +'\t'+name+'\'s Playlist !!\n' + color.END)
print(color.UNDERLINE+"Song              times played \t Taste"+color.END)
file3=open('dataset/'+name+'songs.txt','r')
ct['1\n']=0
ct['2\n']=0
ct['3\n']=0
ct['4\n']=0
ct['5\n']=0
ct['6\n']=0
for li in file3:
    fild=li.split(",")
    print(fild[0]+"\t"+fild[1]+" \t  "+fild[2])
    key=fild[2]
    if key in ct.keys():
        ct[fild[2]]=str(int(ct[fild[2]])+int(fild[1]))
    else:
        ct[fild[2]]='0'
        ct[fild[2]]=str(int(ct[fild[2]])+int(fild[1]))
width=0.5
sizes=[]
x_pos = [0,1,2,3,4,5]
for k in sorted(ct):
    sizes.append(ct[k])

label = "Taste-1","Taste-2","Taste-3","Taste-4","Taste-5","Taste-6"
colors = ['orange', 'skyblue', 'yellowgreen','darkgreen','maroon','lightcoral']
explode = (0.1, 0, 0, 0)  # explode 1st slice

plt.title('Piechart - '+name+'\'s Song distribution wrt taste ',fontsize=16)
plt.pie(sizes, labels=label, colors=colors,autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()
# Out:
# 	salil's Playlist !!
#
# Song              times played 	 Taste
# SOEFSMK12A8C1366EB	5 	  5
#
# SOWVHRT12A6D4FA2A5	13 	  1
#
# SOKCIPE12A8C13BEDE	4 	  6
#
# SOGUVZM12A8C13867A	8 	  2
#
# SOWZGSU12A6D4FB44D	6 	  2
#
# SOLQSCQ12A58A78E1A	11 	  3

# %%
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
plt.style.use('ggplot')

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.BOLD +color.CYAN+ '\t'+name+'\'s songs and universal user\'s count !!\n' + color.END)
file2=open('dataset/'+name+'songs.txt','r')
print(color.UNDERLINE+"Song              Users listened  "+color.END)
j=0
ttsl=[]
co=[]


width=0.7
for line in file2:
    field=line.split(",")
    song=field[0]
    file3=open("dataset\song_countuser.txt","r")
    for li in file3:
        fild=li.split(",")
        if(song==fild[0]):
            uc=fild[1]
            break
    file4=open("dataset\song_count_taste.txt","r")
    for lin in file4:
        fild=lin.split(",")
        if(song==fild[0]):
            tst=fild[2]
            break
    uc=str(int(uc)+1)
    print(field[0]+"\t"+str(uc))
    if(int(tst)==1):
        plt.barh(j,int(uc),width,color=(1, 0.5, 0),edgecolor='black')
    if(int(tst)==2):
        plt.barh(j,int(uc),width,color=(0, 0.5, 1),edgecolor='black')
    if(int(tst)==3):
        plt.barh(j,int(uc),width,color=(0, 0.7, 0.4),edgecolor='black')
    if(int(tst)==4):
        plt.barh(j,int(uc),width,color=(0.3, 0.5, 0.5),edgecolor='black')
    if(int(tst)==5):
        plt.barh(j,int(uc),width,color=(0.8, 0.3, 0.4),edgecolor='black')
    if(int(tst)==6):
        plt.barh(j,int(uc),width,color=(1, 0.4, 0.6),edgecolor='black')
    ttsl.append(field[0])
    plt.text(int(uc) +1, j-0.2, s=uc, size = 9)

    j=j+1
y_pos = np.arange(j)
plt.ylabel('Songs')
plt.xlabel('number of users')
plt.yticks(y_pos,ttsl)
plt.title('Barchart - Playlist songs and number of universal listener',fontsize=16)
red_patch = mpatches.Patch(color=(1, 0.5, 0), label='Taste 1')
h = mpatches.Patch(color=(0, 0.5, 1), label='Taste 2')
r = mpatches.Patch(color=(0, 0.7, 0.4), label='Taste 3')
re = mpatches.Patch(color=(0.3, 0.5, 0.5), label='Taste 4')
red = mpatches.Patch(color=(0.8, 0.3, 0.4), label='Taste 5')
p = mpatches.Patch(color=(1, 0.4, 0.6), label='Taste 6')
han=[red_patch,h,r,re,red,p]
plt.legend(handles=han)
plt.show()
# Out:
# 	salil's songs and universal user's count !!
#
# Song              Users listened
# SOEFSMK12A8C1366EB	3
# SOWVHRT12A6D4FA2A5	6
# SOKCIPE12A8C13BEDE	4
# SOGUVZM12A8C13867A	2
# SOWZGSU12A6D4FB44D	3
# SOLQSCQ12A58A78E1A	2

# %%
file1=open("dataset/triplets.txt","r")
ct ={}
ms=[]
adict={}
em=[]
file2=open('dataset/'+name+'songs.txt','r')
for line in file2:
    fil=line.split(",")
    ms.append(fil[0])
for li in file1:
    fild=li.split(",")
    key=fild[0]
    if key in ct.keys():
        ct[fild[0]].append(fild[1])
    else:
        ct[fild[0]]=[]
        ct[fild[0]].append(fild[1])
file3=open("dataset/try.txt","w+")
for k in ct.keys():
    file3.write(k)
    for ele in ct[k]:
        file3.write(','+ele)
    file3.write('\n')
file3.close()
file4=open("dataset/try.txt","r")
file5=open("dataset/matching.txt","w+")

for line in file4:
    common=0
    fild=line.split(',')
    for x in fild[1:]:
        if x in ms:
            common=common +1
    
    for x in fild[1:]:
        if x not in ms:
            if(str(common)!='0'):
                if str(common) in adict.keys():
                    adict[str(common)].append(x)
                else:
                    adict[str(common)]=[]
                    adict[str(common)].append(ele)

for k in sorted(adict.keys(),reverse=True):
    file5.write(k)
    for ele in adict[k]:
        file5.write(','+ele)
    file5.write('\n')    
file5.close()

import plotly
import plotly.graph_objects as go
file5=open("dataset/matching.txt","r")
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(color.BOLD + color.CYAN+'\t\t\t'+name+'\'s Recommended songs according to collaborative filtering: !!' + color.END)
file2=open("dataset\song_count_taste.txt","r")
j=1
sn=[]
for i in range(1,21):
    sn.append(i)

song=[]
for line in file5:
    if(j==21):
        break
    fild=line.split(',')
    for ele in fild[1:]:
        song.append(ele)
        j=j+1
        if(j==21):
            break
fig = go.Figure(data=[go.Table(header=dict(values=['Sno.', 'Songs']),cells=dict(values=[sn, song]))])
fig.show()
# Out:
# 			salil's Recommended songs according to collaborative filtering: !!
# <div>
#
#
#             <div id="5847016c-9aa4-494f-856d-fb739054105f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5847016c-9aa4-494f-856d-fb739054105f")) {
#                     Plotly.newPlot(
#                         '5847016c-9aa4-494f-856d-fb739054105f',
# ...

# %%
tot=0
for i in sizes:
    tot=tot+int(i)
wgt=[]
for i in sizes:
    x=int(i)/tot
    wgt.append(int(x*15))
tot=0
for i in wgt:
    tot=tot+i

import numpy as np
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
print('\t\t'+name+'\'s Recommended songs according to Popularity and Content Based filtering: !!' )

import plotly.graph_objects as go
file2=open("dataset\song_count_taste.txt","r")
j=0
ttsl=[]
width=0.7
sno=[]
for i in range(1,tot):
    sno.append(i)
songs=[]
count=[]
taste=[]
for line in file2:
    field=line.split(",")
    if(j==tot-1):
        break
    if(int(field[2])==1 and wgt[int(field[2])-1]!=0):
        j=j+1
        songs.append(field[0])
        count.append(field[1])
        taste.append(field[2])
        wgt[int(field[2])-1]=wgt[int(field[2])-1]-1
        plt.barh(j,int(field[1]),width,color=(1, 0.5, 0),edgecolor='black')
        ttsl.append(field[0])
        plt.text(int(field[1]) +10, j, s=field[1], size =9)
    if(int(field[2])==2and wgt[int(field[2])-1]!=0):
        j=j+1
        ttsl.append(field[0])
        songs.append(field[0])
        count.append(field[1])
        taste.append(field[2])
        wgt[int(field[2])-1]=wgt[int(field[2])-1]-1
        plt.barh(j,int(field[1]),width,color=(0, 0.5, 1),edgecolor='black')
        plt.text(int(field[1]) +10, j, s=field[1], size = 9)
    if(int(field[2])==3 and wgt[int(field[2])-1]!=0):
        j=j+1
        ttsl.append(field[0])
        songs.append(field[0])
        count.append(field[1])
        taste.append(field[2])
        wgt[int(field[2])-1]=wgt[int(field[2])-1]-1
        plt.barh(j,int(field[1]),width,color=(0, 0.7, 0.4),edgecolor='black')
        plt.text(int(field[1]) +10, j, s=field[1], size =9)
    if(int(field[2])==4 and wgt[int(field[2])-1]!=0):
        j=j+1
        ttsl.append(field[0])
        songs.append(field[0])
        count.append(field[1])
        taste.append(field[2])
        wgt[int(field[2])-1]=wgt[int(field[2])-1]-1
        plt.barh(j,int(field[1]),width,color=(0.3, 0.5, 0.5),edgecolor='black')
        plt.text(int(field[1]) +10, j, s=field[1], size = 9)
    if(int(field[2])==5 and wgt[int(field[2])-1]!=0):
        j=j+1
        ttsl.append(field[0])
        songs.append(field[0])
        count.append(field[1])
        taste.append(field[2])
        wgt[int(field[2])-1]=wgt[int(field[2])-1]-1
        plt.barh(j,int(field[1]),width,color=(0.8, 0.3, 0.4),edgecolor='black')
        plt.text(int(field[1]) +10, j, s=field[1], size =9)
    if(int(field[2])==6 and wgt[int(field[2])-1]!=0):
        j=j+1
        ttsl.append(field[0])
        songs.append(field[0])
        count.append(field[1])
        taste.append(field[2])
        wgt[int(field[2])-1]=wgt[int(field[2])-1]-1
        plt.barh(j,int(field[1]),width,color=(1, 0.4, 0.6),edgecolor='black')
        plt.text(int(field[1]) +10, j, s=field[1], size = 9)
   
plt.ylabel('Recommended Songs')
plt.xlabel('number of times played')
plt.yticks(sno,ttsl,size=9)
plt.title('Barchart - Top Recommended Songs according to\n Popularity and Content Based filtering',fontsize=14)
red_patch = mpatches.Patch(color=(1, 0.5, 0), label='Taste 1')
h = mpatches.Patch(color=(0, 0.5, 1), label='Taste 2')
r = mpatches.Patch(color=(0, 0.7, 0.4), label='Taste 3')
re = mpatches.Patch(color=(0.3, 0.5, 0.5), label='Taste 4')
red = mpatches.Patch(color=(0.8, 0.3, 0.4), label='Taste 5')
p = mpatches.Patch(color=(1, 0.4, 0.6), label='Taste 6')
han=[red_patch,h,r,re,red,p]
plt.legend(handles=han)
#plt.subplots_adjust(bottom= 0.2, top = 0.98)
fig = go.Figure(data=[go.Table(header=dict(values=['Sno.', 'Songs','Count','Taste']),cells=dict(values=[sno, songs,count,taste]))])
fig.show() 
plt.show()
# Out:
# 		salil's Recommended songs according to Popularity and Content Based filtering: !!
# <div>
#
#
#             <div id="b9e9c416-c18e-4518-b31d-491c2bfce4c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b9e9c416-c18e-4518-b31d-491c2bfce4c2")) {
#                     Plotly.newPlot(
#                         'b9e9c416-c18e-4518-b31d-491c2bfce4c2',
# ...
